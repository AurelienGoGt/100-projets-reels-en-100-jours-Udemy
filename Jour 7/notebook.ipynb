# %% [markdown]
# # Jour 6 : Quiz de maths basique : fonctions

# %% [markdown]
# Objectif :
#
# - Creer une liste vide
# - Creer une fonction pour afficher un menu interactif
# - Creer une boucle pour le programme et generer les infos

# %%
# Etape 1: Initialisation de la liste de courses
shopping_list = []

# Etape 2: Fonction pour afficher le menu
def show_menu():
  print("\n---> Shopping List Menu <---")
  print("1. View the shopping list")
  print("2. Add an item")
  print("3. Remove an item")
  print("4. Clear List")
  print("5. Exit")

# Etape 3: Boucle principale du programme
while True:
  show_menu()
  choice = input("Enter your choice (1-5): ")

  if choice == "1":
    print("\n--- Shopping List ---")
    if not shopping_list:
      print("Your shopping list is empty.")
    else:
      for index, item in enumerate(shopping_list):
        print(f"{index + 1}. {item}")

  elif choice == "2":
    item = input("Enter the item to add: ")
    shopping_list.append(item)
    print(f"{item} has been added to the shopping list.")

  elif choice == "3":
    item = input("Enter the item to remove: ")
    if item in shopping_list:
      shopping_list.remove(item)
      print(f"{item} has been removed from the shopping list.")
    else:
      print(f"{item} is not in the shopping list.")

  elif choice == "4":
    shopping_list.clear()
    print("The shopping list has been cleared.")

  elif choice == "5":
    print("Goodbye! Happy Shopping!")
    break

  else:
    print("Invalid choice. Please try again.")
# Out:
# ---> Shopping List Menu <---
# 1. View the shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear List
# 5. Exit
# Coca has been added to the shopping list.
#
# ---> Shopping List Menu <---
# 1. View the shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear List
# 5. Exit
# Coca has been added to the shopping list.
#
# ---> Shopping List Menu <---
# 1. View the shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear List
# 5. Exit
# Coca has been removed from the shopping list.
#
# ---> Shopping List Menu <---
# 1. View the shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear List
# 5. Exit
# Coca has been removed from the shopping list.
#
# ---> Shopping List Menu <---
# 1. View the shopping list
# 2. Add an item
# 3. Remove an item
# 4. Clear List
# 5. Exit
# Goodbye! Happy Shopping!
# Goodbye! Happy Shopping!
