# %% [markdown]
# # Générateur de message de bienvenue : print & "Hello, World!"

# %% [markdown]
# Objectif 1 :
#
# - Afficher le message Hello, Python World!
# - Afficher le message Le nombre est : 4
# - Afficher le message 2 + 2 = 5

# %%
print("Hello, Python World!")
print("Le nombre est : ", 4)
print("2 + 2 =", 3 + 2)
# Out:
# Hello, Python World!
# Le nombre est :  4
# 2 + 2 = 5

# %% [markdown]
# Objectif 2 :
#
# - Creer une variable Nom et afficher le message : Bonjour, Bienvenue dans le monde de la programmation Python
# - Creer une variable Nom et une variable Loisir et creer un message d'accueil personnalise

# %%
Nom = "Aurelien"
print(f"Bonjour, {Nom}! Bienvenue dans le monde de la programmation Python")
# Out:
# Bonjour, Aurelien! Bienvenue dans le monde de la programmation Python

# %%
# Etape 1 : Recueillir le nom et le loisir de l'utilisateur.
Nom = input("Quel est ton nom? ")
Loisir = input("Quel est ton loisir favori ? ")

# Etape 2: Generer et afficher le message de bienvenue personnalise
print("\n--- Message de bienvenue ---")
print(f"Bonjour, {Nom}! 👋")
print(f"Bienvenue dans le monde de la programmation Python.")
print(f"Ton loisir favori est donc : {Loisir}.")
print(f"Sois pret a creer quelque chose d'incroyable aujourd'hui.")
# Out:
# --- Message de bienvenue ---
# Bonjour, Aurelien! 👋
# Bienvenue dans le monde de la programmation Python.
# Ton loisir favori est donc : La lecture.
# Sois pret a creer quelque chose d'incroyable aujourd'hui.
